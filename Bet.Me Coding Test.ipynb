# %% [markdown]
# ### Technical Resources - Python Jupyter and SQLite3 (Python package for Database)

# %% [markdown]
# # Step 1: Create database and table using SQLite to store the football data

# %%
## Python Package Used

import sqlite3
from pandas.io.json import json_normalize
import pandas as pd 
import datetime
import http.client
import json
import http.client

# %% [markdown]
# ### Setup database connectio/ SQLite

# %%
conn = sqlite3.connect('test.db')   
print(conn)
# Out:
# <sqlite3.Connection object at 0x00C860A0>

# %% [markdown]
# ### Create Football Data Table

# %%
conn.execute('drop table if exists football') # we can also drop the table with this

# %%
# Create the Football Data Table 
conn.execute('''CREATE TABLE football

    (id          INT PRIMARY KEY NOT NULL,
    div         VARCHAR       NOT NULL,
    date_time   TIMESTAMP     NOT NULL,
    home_team   VARCHAR       NOT NULL,
    away_team   VARCHAR       NOT NULL,
    fthg        INT           DEFAULT(0),
    ftag        INT           DEFAULT(0));''')

# %% [markdown]
# #### Test Table Exist

# %%
conn.execute("SELECT * from football") # check if the table exist

# %% [markdown]
# # Step 2:  Connect to Football data website to retrieve the data

# %%
# Retrive Football data from https://www.football-data.co.uk

connection = http.client.HTTPConnection('api.football-data.org')
headers = { 'X-Auth-Token': 'f403d7fd891241aebfb853bc39f7f234' }
connection.request('GET', '/v2/matches?competitions=PL,PL&status=FINISHED&dateFrom=2019-12-26&dateTo=2020-01-05', None, headers )
#connection.request('GET', '/v2/competitions/2021/matches', None, headers )

response = json.loads(connection.getresponse().read().decode())

# %%
response
# Out:
# {'count': 30,
#  'filters': {'competitions': [2021],
#   'dateFrom': '2019-12-26',
#   'dateTo': '2020-01-05',
#   'permission': 'TIER_ONE',
#   'status': ['FINISHED']},
#  'matches': [{'awayTeam': {'id': 397, 'name': 'Brighton & Hove Albion FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 73, 'name': 'Tottenham Hotspur FC'},
#    'id': 264524,
#    'lastUpdated': '2019-12-26T23:59:24Z',
#    'matchday': 19,
#    'referees': [{'id': 11503, 'name': 'Graham Scott', 'nationality': None},
#     {'id': 11424, 'name': 'Neil Davies', 'nationality': None},
#     {'id': 137388, 'name': None, 'nationality': None},
#     {'id': 11396, 'name': 'Tim Robinson', 'nationality': None},
#     {'id': 11575, 'name': 'Mike Dean', 'nationality': None},
#     {'id': 11521, 'name': 'Mark Scholes', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 1, 'homeTeam': 2},
#     'halfTime': {'awayTeam': 1, 'homeTeam': 0},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'HOME_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-26T12:30:00Z'},
#   {'awayTeam': {'id': 68, 'name': 'Norwich City FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 58, 'name': 'Aston Villa FC'},
#    'id': 264522,
#    'lastUpdated': '2019-12-26T23:59:24Z',
#    'matchday': 19,
#    'referees': [{'id': 11443, 'name': 'Chris Kavanagh', 'nationality': None},
#     {'id': 98555, 'name': None, 'nationality': None},
#     {'id': 11615, 'name': 'Adam Nunn', 'nationality': None},
#     {'id': 11626, 'name': 'Matt Donohue', 'nationality': None},
#     {'id': 11479, 'name': 'Lee Mason', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 0, 'homeTeam': 1},
#     'halfTime': {'awayTeam': 0, 'homeTeam': 0},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'HOME_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-26T15:00:00Z'},
#   {'awayTeam': {'id': 340, 'name': 'Southampton FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 61, 'name': 'Chelsea FC'},
#    'id': 264523,
#    'lastUpdated': '2019-12-26T23:59:24Z',
#    'matchday': 19,
#    'referees': [{'id': 11567, 'name': 'Jonathan Moss', 'nationality': None},
#     {'id': 11531, 'name': 'Marc Perry', 'nationality': None},
#     {'id': 11480, 'name': 'Eddie Smart', 'nationality': None},
#     {'id': 9382, 'name': 'Gavin Ward', 'nationality': None},
#     {'id': 11430, 'name': 'Simon Hooper', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 2, 'homeTeam': 0},
#     'halfTime': {'awayTeam': 1, 'homeTeam': 0},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'AWAY_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-26T15:00:00Z'},
#   {'awayTeam': {'id': 328, 'name': 'Burnley FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 62, 'name': 'Everton FC'},
#    'id': 264525,
#    'lastUpdated': '2019-12-26T23:59:24Z',
#    'matchday': 19,
#    'referees': [{'id': 11580, 'name': 'Anthony Taylor', 'nationality': None},
#     {'id': 11581, 'name': 'Gary Beswick', 'nationality': None},
#     {'id': 11611, 'name': 'Scott Ledger', 'nationality': None},
#     {'id': 11472, 'name': 'Jeremy Simpson', 'nationality': None},
#     {'id': 11520, 'name': 'Paul Tierney', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 0, 'homeTeam': 1},
#     'halfTime': {'awayTeam': 0, 'homeTeam': 0},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'HOME_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-26T15:00:00Z'},
#   {'awayTeam': {'id': 346, 'name': 'Watford FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 356, 'name': 'Sheffield United FC'},
#    'id': 264527,
#    'lastUpdated': '2019-12-26T23:59:24Z',
#    'matchday': 19,
#    'referees': [{'id': 11556, 'name': 'David Coote', 'nationality': None},
#     {'id': 11552, 'name': 'Peter Kirkup', 'nationality': None},
#     {'id': 11425, 'name': 'Nicholas Hopton', 'nationality': None},
#     {'id': 11689, 'name': 'Ben Toner', 'nationality': None},
#     {'id': 11551, 'name': 'Martin Atkinson', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 1, 'homeTeam': 1},
#     'halfTime': {'awayTeam': 1, 'homeTeam': 1},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'DRAW'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-26T15:00:00Z'},
#   {'awayTeam': {'id': 563, 'name': 'West Ham United FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 354, 'name': 'Crystal Palace FC'},
#    'id': 264529,
#    'lastUpdated': '2019-12-26T23:59:24Z',
#    'matchday': 19,
#    'referees': [{'id': 11610, 'name': 'Andre Marriner', 'nationality': None},
#     {'id': 11570, 'name': 'Harry Lennard', 'nationality': None},
#     {'id': 11586, 'name': 'Richard West', 'nationality': None},
#     {'id': 11561, 'name': 'Tom Nield', 'nationality': None},
#     {'id': 11423, 'name': 'Andy Madley', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 1, 'homeTeam': 2},
#     'halfTime': {'awayTeam': 0, 'homeTeam': 0},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'HOME_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-26T15:00:00Z'},
#   {'awayTeam': {'id': 57, 'name': 'Arsenal FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 1044, 'name': 'AFC Bournemouth'},
#    'id': 264530,
#    'lastUpdated': '2019-12-26T23:59:24Z',
#    'matchday': 19,
#    'referees': [{'id': 11494, 'name': 'Stuart Attwell', 'nationality': None},
#     {'id': 11438, 'name': 'Dan Cook', 'nationality': None},
#     {'id': 11504, 'name': 'Simon Long', 'nationality': None},
#     {'id': 11290, 'name': 'Steve Martin', 'nationality': None},
#     {'id': 11309, 'name': 'Peter Bankes', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 1, 'homeTeam': 1},
#     'halfTime': {'awayTeam': 0, 'homeTeam': 1},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'DRAW'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-26T15:00:00Z'},
#   {'awayTeam': {'id': 67, 'name': 'Newcastle United FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 66, 'name': 'Manchester United FC'},
#    'id': 264526,
#    'lastUpdated': '2019-12-27T03:25:01Z',
#    'matchday': 19,
#    'referees': [{'id': 11487, 'name': 'Kevin Friend', 'nationality': None},
#     {'id': 11595, 'name': 'Adrian Holmes', 'nationality': None},
#     {'id': 11576, 'name': 'Darren Cann', 'nationality': None},
#     {'id': 11287, 'name': 'Oliver Langford', 'nationality': None},
#     {'id': 11575, 'name': 'Mike Dean', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 1, 'homeTeam': 4},
#     'halfTime': {'awayTeam': 1, 'homeTeam': 3},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'HOME_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-26T17:30:00Z'},
#   {'awayTeam': {'id': 64, 'name': 'Liverpool FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 338, 'name': 'Leicester City FC'},
#    'id': 264528,
#    'lastUpdated': '2019-12-27T03:30:01Z',
#    'matchday': 19,
#    'referees': [{'id': 11605, 'name': 'Michael Oliver', 'nationality': None},
#     {'id': 11564, 'name': 'Stuart Burt', 'nationality': None},
#     {'id': 11488, 'name': 'Simon Bennett', 'nationality': None},
#     {'id': 11585, 'name': 'Craig Pawson', 'nationality': None},
#     {'id': 11520, 'name': 'Paul Tierney', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 4, 'homeTeam': 0},
#     'halfTime': {'awayTeam': 1, 'homeTeam': 0},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'AWAY_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-26T20:00:00Z'},
#   {'awayTeam': {'id': 65, 'name': 'Manchester City FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 76, 'name': 'Wolverhampton Wanderers FC'},
#    'id': 264521,
#    'lastUpdated': '2019-12-27T23:59:23Z',
#    'matchday': 19,
#    'referees': [{'id': 11551, 'name': 'Martin Atkinson', 'nationality': None},
#     {'id': 11530, 'name': 'Lee Betts', 'nationality': None},
#     {'id': 11606, 'name': 'Constantine Hatzidakis', 'nationality': None},
#     {'id': 11610, 'name': 'Andre Marriner', 'nationality': None},
#     {'id': 11556, 'name': 'David Coote', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 2, 'homeTeam': 3},
#     'halfTime': {'awayTeam': 1, 'homeTeam': 0},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'HOME_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-27T19:45:00Z'},
#   {'awayTeam': {'id': 1044, 'name': 'AFC Bournemouth'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 397, 'name': 'Brighton & Hove Albion FC'},
#    'id': 264539,
#    'lastUpdated': '2019-12-28T23:59:24Z',
#    'matchday': 20,
#    'referees': [{'id': 11520, 'name': 'Paul Tierney', 'nationality': None},
#     {'id': 11438, 'name': 'Dan Cook', 'nationality': None},
#     {'id': 11531, 'name': 'Marc Perry', 'nationality': None},
#     {'id': 11324, 'name': 'James Linington', 'nationality': None},
#     {'id': 11503, 'name': 'Graham Scott', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 0, 'homeTeam': 2},
#     'halfTime': {'awayTeam': 0, 'homeTeam': 1},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'HOME_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-28T12:30:00Z'},
#   {'awayTeam': {'id': 62, 'name': 'Everton FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 67, 'name': 'Newcastle United FC'},
#    'id': 264533,
#    'lastUpdated': '2019-12-28T23:59:24Z',
#    'matchday': 20,
#    'referees': [{'id': 11479, 'name': 'Lee Mason', 'nationality': None},
#     {'id': 11611, 'name': 'Scott Ledger', 'nationality': None},
#     {'id': 11521, 'name': 'Mark Scholes', 'nationality': None},
#     {'id': 11378, 'name': 'Tony Harrington', 'nationality': None},
#     {'id': 11585, 'name': 'Craig Pawson', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 2, 'homeTeam': 1},
#     'halfTime': {'awayTeam': 1, 'homeTeam': 0},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'AWAY_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-28T15:00:00Z'},
#   {'awayTeam': {'id': 354, 'name': 'Crystal Palace FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 340, 'name': 'Southampton FC'},
#    'id': 264538,
#    'lastUpdated': '2019-12-28T23:59:24Z',
#    'matchday': 20,
#    'referees': [{'id': 11423, 'name': 'Andy Madley', 'nationality': None},
#     {'id': 11431, 'name': 'Daniel Robathan', 'nationality': None},
#     {'id': 11544, 'name': 'Simon Beck', 'nationality': None},
#     {'id': 11317, 'name': 'Darren Bond', 'nationality': None},
#     {'id': 11610, 'name': 'Andre Marriner', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 1, 'homeTeam': 1},
#     'halfTime': {'awayTeam': 0, 'homeTeam': 0},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'DRAW'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-28T15:00:00Z'},
#   {'awayTeam': {'id': 58, 'name': 'Aston Villa FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 346, 'name': 'Watford FC'},
#    'id': 264540,
#    'lastUpdated': '2019-12-28T23:59:24Z',
#    'matchday': 20,
#    'referees': [{'id': 11430, 'name': 'Simon Hooper', 'nationality': None},
#     {'id': 11488, 'name': 'Simon Bennett', 'nationality': None},
#     {'id': 11505, 'name': 'Derek Eaton', 'nationality': None},
#     {'id': 11290, 'name': 'Steve Martin', 'nationality': None},
#     {'id': 11567, 'name': 'Jonathan Moss', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 0, 'homeTeam': 3},
#     'halfTime': {'awayTeam': 0, 'homeTeam': 1},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'HOME_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-28T15:00:00Z'},
#   {'awayTeam': {'id': 73, 'name': 'Tottenham Hotspur FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 68, 'name': 'Norwich City FC'},
#    'id': 264535,
#    'lastUpdated': '2019-12-29T03:00:01Z',
#    'matchday': 20,
#    'referees': [{'id': 11487, 'name': 'Kevin Friend', 'nationality': None},
#     {'id': 11480, 'name': 'Eddie Smart', 'nationality': None},
#     {'id': 11595, 'name': 'Adrian Holmes', 'nationality': None},
#     {'id': 11486, 'name': 'Dean Whitestone', 'nationality': None},
#     {'id': 11443, 'name': 'Chris Kavanagh', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 2, 'homeTeam': 2},
#     'halfTime': {'awayTeam': 0, 'homeTeam': 1},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'DRAW'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-28T17:30:00Z'},
#   {'awayTeam': {'id': 338, 'name': 'Leicester City FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 563, 'name': 'West Ham United FC'},
#    'id': 264537,
#    'lastUpdated': '2019-12-29T03:05:01Z',
#    'matchday': 20,
#    'referees': [{'id': 11556, 'name': 'David Coote', 'nationality': None},
#     {'id': 11570, 'name': 'Harry Lennard', 'nationality': None},
#     {'id': 11425, 'name': 'Nicholas Hopton', 'nationality': None},
#     {'id': 11494, 'name': 'Stuart Attwell', 'nationality': None},
#     {'id': 11551, 'name': 'Martin Atkinson', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 2, 'homeTeam': 1},
#     'halfTime': {'awayTeam': 1, 'homeTeam': 1},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'AWAY_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-28T17:30:00Z'},
#   {'awayTeam': {'id': 66, 'name': 'Manchester United FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 328, 'name': 'Burnley FC'},
#    'id': 264536,
#    'lastUpdated': '2019-12-29T03:00:01Z',
#    'matchday': 20,
#    'referees': [{'id': 11575, 'name': 'Mike Dean', 'nationality': None},
#     {'id': 11495, 'name': 'Ian Hussin', 'nationality': None},
#     {'id': 11576, 'name': 'Darren Cann', 'nationality': None},
#     {'id': 11580, 'name': 'Anthony Taylor', 'nationality': None},
#     {'id': 11605, 'name': 'Michael Oliver', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 2, 'homeTeam': 0},
#     'halfTime': {'awayTeam': 1, 'homeTeam': 0},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'AWAY_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-28T19:45:00Z'},
#   {'awayTeam': {'id': 61, 'name': 'Chelsea FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 57, 'name': 'Arsenal FC'},
#    'id': 264534,
#    'lastUpdated': '2019-12-29T23:59:23Z',
#    'matchday': 20,
#    'referees': [{'id': 11585, 'name': 'Craig Pawson', 'nationality': None},
#     {'id': 11530, 'name': 'Lee Betts', 'nationality': None},
#     {'id': 11586, 'name': 'Richard West', 'nationality': None},
#     {'id': 11551, 'name': 'Martin Atkinson', 'nationality': None},
#     {'id': 11605, 'name': 'Michael Oliver', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 2, 'homeTeam': 1},
#     'halfTime': {'awayTeam': 0, 'homeTeam': 1},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'AWAY_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-29T14:00:00Z'},
#   {'awayTeam': {'id': 76, 'name': 'Wolverhampton Wanderers FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 64, 'name': 'Liverpool FC'},
#    'id': 264531,
#    'lastUpdated': '2019-12-29T23:59:23Z',
#    'matchday': 20,
#    'referees': [{'id': 11580, 'name': 'Anthony Taylor', 'nationality': None},
#     {'id': 11581, 'name': 'Gary Beswick', 'nationality': None},
#     {'id': 11615, 'name': 'Adam Nunn', 'nationality': None},
#     {'id': 11575, 'name': 'Mike Dean', 'nationality': None},
#     {'id': 11430, 'name': 'Simon Hooper', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 0, 'homeTeam': 1},
#     'halfTime': {'awayTeam': 0, 'homeTeam': 1},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'HOME_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-29T16:30:00Z'},
#   {'awayTeam': {'id': 356, 'name': 'Sheffield United FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 65, 'name': 'Manchester City FC'},
#    'id': 264532,
#    'lastUpdated': '2019-12-30T06:20:00Z',
#    'matchday': 20,
#    'referees': [{'id': 11443, 'name': 'Chris Kavanagh', 'nationality': None},
#     {'id': 98555, 'name': None, 'nationality': None},
#     {'id': 11606, 'name': 'Constantine Hatzidakis', 'nationality': None},
#     {'id': 11327, 'name': 'John Brooks', 'nationality': None},
#     {'id': 11494, 'name': 'Stuart Attwell', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 0, 'homeTeam': 2},
#     'halfTime': {'awayTeam': 0, 'homeTeam': 0},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'HOME_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2019-12-29T18:00:00Z'},
#   {'awayTeam': {'id': 58, 'name': 'Aston Villa FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 328, 'name': 'Burnley FC'},
#    'id': 264546,
#    'lastUpdated': '2020-01-01T23:59:24Z',
#    'matchday': 21,
#    'referees': [{'id': 11605, 'name': 'Michael Oliver', 'nationality': None},
#     {'id': 11564, 'name': 'Stuart Burt', 'nationality': None},
#     {'id': 11488, 'name': 'Simon Bennett', 'nationality': None},
#     {'id': 11378, 'name': 'Tony Harrington', 'nationality': None},
#     {'id': 23568, 'name': 'Jarred Gillett', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 2, 'homeTeam': 1},
#     'halfTime': {'awayTeam': 2, 'homeTeam': 0},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'AWAY_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2020-01-01T12:30:00Z'},
#   {'awayTeam': {'id': 61, 'name': 'Chelsea FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 397, 'name': 'Brighton & Hove Albion FC'},
#    'id': 264549,
#    'lastUpdated': '2020-01-01T23:59:24Z',
#    'matchday': 21,
#    'referees': [{'id': 11494, 'name': 'Stuart Attwell', 'nationality': None},
#     {'id': 11530, 'name': 'Lee Betts', 'nationality': None},
#     {'id': 11615, 'name': 'Adam Nunn', 'nationality': None},
#     {'id': 9382, 'name': 'Gavin Ward', 'nationality': None},
#     {'id': 11556, 'name': 'David Coote', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 1, 'homeTeam': 1},
#     'halfTime': {'awayTeam': 1, 'homeTeam': 0},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'DRAW'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2020-01-01T12:30:00Z'},
#   {'awayTeam': {'id': 338, 'name': 'Leicester City FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 67, 'name': 'Newcastle United FC'},
#    'id': 264543,
#    'lastUpdated': '2020-01-01T23:59:24Z',
#    'matchday': 21,
#    'referees': [{'id': 11551, 'name': 'Martin Atkinson', 'nationality': None},
#     {'id': 11581, 'name': 'Gary Beswick', 'nationality': None},
#     {'id': 11425, 'name': 'Nicholas Hopton', 'nationality': None},
#     {'id': 58084, 'name': 'Leigh Doughty', 'nationality': None},
#     {'id': 11309, 'name': 'Peter Bankes', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 3, 'homeTeam': 0},
#     'halfTime': {'awayTeam': 2, 'homeTeam': 0},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'AWAY_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2020-01-01T15:00:00Z'},
#   {'awayTeam': {'id': 73, 'name': 'Tottenham Hotspur FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 340, 'name': 'Southampton FC'},
#    'id': 264548,
#    'lastUpdated': '2020-01-01T23:59:24Z',
#    'matchday': 21,
#    'referees': [{'id': 11575, 'name': 'Mike Dean', 'nationality': None},
#     {'id': 11495, 'name': 'Ian Hussin', 'nationality': None},
#     {'id': 11431, 'name': 'Daniel Robathan', 'nationality': None},
#     {'id': 11519, 'name': 'Keith Stroud', 'nationality': None},
#     {'id': 11580, 'name': 'Anthony Taylor', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 0, 'homeTeam': 1},
#     'halfTime': {'awayTeam': 0, 'homeTeam': 1},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'HOME_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2020-01-01T15:00:00Z'},
#   {'awayTeam': {'id': 76, 'name': 'Wolverhampton Wanderers FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 346, 'name': 'Watford FC'},
#    'id': 264550,
#    'lastUpdated': '2020-01-01T23:59:24Z',
#    'matchday': 21,
#    'referees': [{'id': 11423, 'name': 'Andy Madley', 'nationality': None},
#     {'id': 11595, 'name': 'Adrian Holmes', 'nationality': None},
#     {'id': 11544, 'name': 'Simon Beck', 'nationality': None},
#     {'id': 11497, 'name': 'Charles Breakspear', 'nationality': None},
#     {'id': 11430, 'name': 'Simon Hooper', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 1, 'homeTeam': 2},
#     'halfTime': {'awayTeam': 0, 'homeTeam': 1},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'HOME_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2020-01-01T15:00:00Z'},
#   {'awayTeam': {'id': 62, 'name': 'Everton FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 65, 'name': 'Manchester City FC'},
#    'id': 264542,
#    'lastUpdated': '2020-01-02T12:55:00Z',
#    'matchday': 21,
#    'referees': [{'id': 11610, 'name': 'Andre Marriner', 'nationality': None},
#     {'id': 11611, 'name': 'Scott Ledger', 'nationality': None},
#     {'id': 11504, 'name': 'Simon Long', 'nationality': None},
#     {'id': 11487, 'name': 'Kevin Friend', 'nationality': None},
#     {'id': 11556, 'name': 'David Coote', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 1, 'homeTeam': 2},
#     'halfTime': {'awayTeam': 0, 'homeTeam': 0},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'HOME_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2020-01-01T17:30:00Z'},
#   {'awayTeam': {'id': 354, 'name': 'Crystal Palace FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 68, 'name': 'Norwich City FC'},
#    'id': 264545,
#    'lastUpdated': '2020-01-02T05:00:00Z',
#    'matchday': 21,
#    'referees': [{'id': 11567, 'name': 'Jonathan Moss', 'nationality': None},
#     {'id': 11531, 'name': 'Marc Perry', 'nationality': None},
#     {'id': 11480, 'name': 'Eddie Smart', 'nationality': None},
#     {'id': 11476, 'name': 'Andy Woolmer', 'nationality': None},
#     {'id': 23568, 'name': 'Jarred Gillett', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 1, 'homeTeam': 1},
#     'halfTime': {'awayTeam': 0, 'homeTeam': 1},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'DRAW'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2020-01-01T17:30:00Z'},
#   {'awayTeam': {'id': 1044, 'name': 'AFC Bournemouth'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 563, 'name': 'West Ham United FC'},
#    'id': 264547,
#    'lastUpdated': '2020-01-02T05:00:00Z',
#    'matchday': 21,
#    'referees': [{'id': 11503, 'name': 'Graham Scott', 'nationality': None},
#     {'id': 11424, 'name': 'Neil Davies', 'nationality': None},
#     {'id': 11521, 'name': 'Mark Scholes', 'nationality': None},
#     {'id': 11396, 'name': 'Tim Robinson', 'nationality': None},
#     {'id': 11479, 'name': 'Lee Mason', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 0, 'homeTeam': 4},
#     'halfTime': {'awayTeam': 0, 'homeTeam': 3},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'HOME_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2020-01-01T17:30:00Z'},
#   {'awayTeam': {'id': 66, 'name': 'Manchester United FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 57, 'name': 'Arsenal FC'},
#    'id': 264544,
#    'lastUpdated': '2020-01-02T04:50:00Z',
#    'matchday': 21,
#    'referees': [{'id': 11443, 'name': 'Chris Kavanagh', 'nationality': None},
#     {'id': 98555, 'name': None, 'nationality': None},
#     {'id': 11606, 'name': 'Constantine Hatzidakis', 'nationality': None},
#     {'id': 11585, 'name': 'Craig Pawson', 'nationality': None},
#     {'id': 11520, 'name': 'Paul Tierney', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 0, 'homeTeam': 2},
#     'halfTime': {'awayTeam': 0, 'homeTeam': 2},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'HOME_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2020-01-01T20:00:00Z'},
#   {'awayTeam': {'id': 356, 'name': 'Sheffield United FC'},
#    'competition': {'id': 2021, 'name': 'Premier League'},
#    'group': 'Regular Season',
#    'homeTeam': {'id': 64, 'name': 'Liverpool FC'},
#    'id': 264541,
#    'lastUpdated': '2020-01-03T15:15:00Z',
#    'matchday': 21,
#    'referees': [{'id': 11520, 'name': 'Paul Tierney', 'nationality': None},
#     {'id': 11438, 'name': 'Dan Cook', 'nationality': None},
#     {'id': 11570, 'name': 'Harry Lennard', 'nationality': None},
#     {'id': 11580, 'name': 'Anthony Taylor', 'nationality': None},
#     {'id': 11487, 'name': 'Kevin Friend', 'nationality': None}],
#    'score': {'duration': 'REGULAR',
#     'extraTime': {'awayTeam': None, 'homeTeam': None},
#     'fullTime': {'awayTeam': 0, 'homeTeam': 2},
#     'halfTime': {'awayTeam': 0, 'homeTeam': 1},
#     'penalties': {'awayTeam': None, 'homeTeam': None},
#     'winner': 'HOME_TEAM'},
#    'season': {'currentMatchday': 23,
#     'endDate': '2020-05-17',
#     'id': 468,
#     'startDate': '2019-08-09',
#     'winner': None},
#    'stage': 'REGULAR_SEASON',
#    'status': 'FINISHED',
#    'utcDate': '2020-01-02T20:00:00Z'}]}

# %% [markdown]
# #### Normalised the football json data and transform into Pandas dataframe

# %%
Football_data = json_normalize(response['matches']) 
Football_data.head(5)
# Out:
#    awayTeam.id              awayTeam.name  competition.id competition.name  \
# 0          397  Brighton & Hove Albion FC            2021   Premier League
# 1           68            Norwich City FC            2021   Premier League
# 2          340             Southampton FC            2021   Premier League
# 3          328                 Burnley FC            2021   Premier League
# 4          346                 Watford FC            2021   Premier League
#
#             group  homeTeam.id         homeTeam.name      id  \
# 0  Regular Season           73  Tottenham Hotspur FC  264524
# 1  Regular Season           58        Aston Villa FC  264522
# 2  Regular Season           61            Chelsea FC  264523
# 3  Regular Season           62            Everton FC  264525
# 4  Regular Season          356   Sheffield United FC  264527
#
#             lastUpdated  matchday          ...           \
# 0  2019-12-26T23:59:24Z        19          ...
# 1  2019-12-26T23:59:24Z        19          ...
# 2  2019-12-26T23:59:24Z        19          ...
# 3  2019-12-26T23:59:24Z        19          ...
# 4  2019-12-26T23:59:24Z        19          ...
#
#   score.penalties.homeTeam score.winner season.currentMatchday season.endDate  \
# 0                     None    HOME_TEAM                     23     2020-05-17
# 1                     None    HOME_TEAM                     23     2020-05-17
# 2                     None    AWAY_TEAM                     23     2020-05-17
# 3                     None    HOME_TEAM                     23     2020-05-17
# 4                     None         DRAW                     23     2020-05-17
#
#    season.id  season.startDate  season.winner           stage    status  \
# 0        468        2019-08-09           None  REGULAR_SEASON  FINISHED
# 1        468        2019-08-09           None  REGULAR_SEASON  FINISHED
# 2        468        2019-08-09           None  REGULAR_SEASON  FINISHED
# 3        468        2019-08-09           None  REGULAR_SEASON  FINISHED
# 4        468        2019-08-09           None  REGULAR_SEASON  FINISHED
#
#                 utcDate
# 0  2019-12-26T12:30:00Z
# 1  2019-12-26T15:00:00Z
# 2  2019-12-26T15:00:00Z
# 3  2019-12-26T15:00:00Z
# 4  2019-12-26T15:00:00Z
#
# [5 rows x 29 columns]

# %% [markdown]
# ###  Data Processing
# ###### 1. Select  columns of interest
# ###### 2. Format date to timestamp
# ###### 3. Rename coloum to match database table

# %%
Football_data['utcDate'] = pd.to_datetime(Football_data['utcDate'])
Football_data1= Football_data.rename(columns={'utcDate': 'date_time', 'competition.name': 'div', 'homeTeam.name': 'home_team', 
'awayTeam.name': 'away_team', 'score.fullTime.homeTeam':'fthg','score.fullTime.awayTeam':'ftag'})
Football_data1= Football_data.rename(columns={'utcDate': 'date_time', 'competition.name': 'div','homeTeam.name': 'home_team', 'awayTeam.name': 'away_team', 'score.fullTime.homeTeam':'fthg','score.fullTime.awayTeam':'ftag'})
Football_data2=Football_data1[['id','date_time', 'div', 'away_team', 'home_team','ftag','fthg']]
Football_data2=Football_data2.set_index('id')
Football_data2.columns
Football_data2
# Out:
#                  date_time             div                   away_team  \
# id
# 264524 2019-12-26 12:30:00  Premier League   Brighton & Hove Albion FC
# 264522 2019-12-26 15:00:00  Premier League             Norwich City FC
# 264523 2019-12-26 15:00:00  Premier League              Southampton FC
# 264525 2019-12-26 15:00:00  Premier League                  Burnley FC
# 264527 2019-12-26 15:00:00  Premier League                  Watford FC
# 264529 2019-12-26 15:00:00  Premier League          West Ham United FC
# 264530 2019-12-26 15:00:00  Premier League                  Arsenal FC
# 264526 2019-12-26 17:30:00  Premier League         Newcastle United FC
# 264528 2019-12-26 20:00:00  Premier League                Liverpool FC
# 264521 2019-12-27 19:45:00  Premier League          Manchester City FC
# 264539 2019-12-28 12:30:00  Premier League             AFC Bournemouth
# 264533 2019-12-28 15:00:00  Premier League                  Everton FC
# 264538 2019-12-28 15:00:00  Premier League           Crystal Palace FC
# 264540 2019-12-28 15:00:00  Premier League              Aston Villa FC
# 264535 2019-12-28 17:30:00  Premier League        Tottenham Hotspur FC
# 264537 2019-12-28 17:30:00  Premier League           Leicester City FC
# 264536 2019-12-28 19:45:00  Premier League        Manchester United FC
# 264534 2019-12-29 14:00:00  Premier League                  Chelsea FC
# 264531 2019-12-29 16:30:00  Premier League  Wolverhampton Wanderers FC
# 264532 2019-12-29 18:00:00  Premier League         Sheffield United FC
# 264546 2020-01-01 12:30:00  Premier League              Aston Villa FC
# 264549 2020-01-01 12:30:00  Premier League                  Chelsea FC
# 264543 2020-01-01 15:00:00  Premier League           Leicester City FC
# 264548 2020-01-01 15:00:00  Premier League        Tottenham Hotspur FC
# 264550 2020-01-01 15:00:00  Premier League  Wolverhampton Wanderers FC
# 264542 2020-01-01 17:30:00  Premier League                  Everton FC
# 264545 2020-01-01 17:30:00  Premier League           Crystal Palace FC
# 264547 2020-01-01 17:30:00  Premier League             AFC Bournemouth
# 264544 2020-01-01 20:00:00  Premier League        Manchester United FC
# 264541 2020-01-02 20:00:00  Premier League         Sheffield United FC
#
#                          home_team  ftag  fthg
# id
# 264524        Tottenham Hotspur FC     1     2
# 264522              Aston Villa FC     0     1
# 264523                  Chelsea FC     2     0
# 264525                  Everton FC     0     1
# 264527         Sheffield United FC     1     1
# 264529           Crystal Palace FC     1     2
# 264530             AFC Bournemouth     1     1
# 264526        Manchester United FC     1     4
# 264528           Leicester City FC     4     0
# 264521  Wolverhampton Wanderers FC     2     3
# 264539   Brighton & Hove Albion FC     0     2
# 264533         Newcastle United FC     2     1
# 264538              Southampton FC     1     1
# 264540                  Watford FC     0     3
# 264535             Norwich City FC     2     2
# 264537          West Ham United FC     2     1
# 264536                  Burnley FC     2     0
# 264534                  Arsenal FC     2     1
# 264531                Liverpool FC     0     1
# 264532          Manchester City FC     0     2
# 264546                  Burnley FC     2     1
# 264549   Brighton & Hove Albion FC     1     1
# 264543         Newcastle United FC     3     0
# 264548              Southampton FC     0     1
# 264550                  Watford FC     1     2
# 264542          Manchester City FC     1     2
# 264545             Norwich City FC     1     1
# 264547          West Ham United FC     0     4
# 264544                  Arsenal FC     0     2
# 264541                Liverpool FC     0     2

# %% [markdown]
# #### Insert Football Data into Football Table in Database

# %%
Football_data2.to_sql('football', con=conn, if_exists='append')

# %% [markdown]
# #### Result

# %%
for row in conn.execute('SELECT * FROM football'):
        print (row)
# Out:
# (264524, 'Premier League', '2019-12-26 12:30:00', 'Tottenham Hotspur FC', 'Brighton & Hove Albion FC', 2, 1)
# (264522, 'Premier League', '2019-12-26 15:00:00', 'Aston Villa FC', 'Norwich City FC', 1, 0)
# (264523, 'Premier League', '2019-12-26 15:00:00', 'Chelsea FC', 'Southampton FC', 0, 2)
# (264525, 'Premier League', '2019-12-26 15:00:00', 'Everton FC', 'Burnley FC', 1, 0)
# (264527, 'Premier League', '2019-12-26 15:00:00', 'Sheffield United FC', 'Watford FC', 1, 1)
# (264529, 'Premier League', '2019-12-26 15:00:00', 'Crystal Palace FC', 'West Ham United FC', 2, 1)
# (264530, 'Premier League', '2019-12-26 15:00:00', 'AFC Bournemouth', 'Arsenal FC', 1, 1)
# (264526, 'Premier League', '2019-12-26 17:30:00', 'Manchester United FC', 'Newcastle United FC', 4, 1)
# (264528, 'Premier League', '2019-12-26 20:00:00', 'Leicester City FC', 'Liverpool FC', 0, 4)
# (264521, 'Premier League', '2019-12-27 19:45:00', 'Wolverhampton Wanderers FC', 'Manchester City FC', 3, 2)
# (264539, 'Premier League', '2019-12-28 12:30:00', 'Brighton & Hove Albion FC', 'AFC Bournemouth', 2, 0)
# (264533, 'Premier League', '2019-12-28 15:00:00', 'Newcastle United FC', 'Everton FC', 1, 2)
# (264538, 'Premier League', '2019-12-28 15:00:00', 'Southampton FC', 'Crystal Palace FC', 1, 1)
# (264540, 'Premier League', '2019-12-28 15:00:00', 'Watford FC', 'Aston Villa FC', 3, 0)
# (264535, 'Premier League', '2019-12-28 17:30:00', 'Norwich City FC', 'Tottenham Hotspur FC', 2, 2)
# (264537, 'Premier League', '2019-12-28 17:30:00', 'West Ham United FC', 'Leicester City FC', 1, 2)
# (264536, 'Premier League', '2019-12-28 19:45:00', 'Burnley FC', 'Manchester United FC', 0, 2)
# (264534, 'Premier League', '2019-12-29 14:00:00', 'Arsenal FC', 'Chelsea FC', 1, 2)
# (264531, 'Premier League', '2019-12-29 16:30:00', 'Liverpool FC', 'Wolverhampton Wanderers FC', 1, 0)
# (264532, 'Premier League', '2019-12-29 18:00:00', 'Manchester City FC', 'Sheffield United FC', 2, 0)
# (264546, 'Premier League', '2020-01-01 12:30:00', 'Burnley FC', 'Aston Villa FC', 1, 2)
# (264549, 'Premier League', '2020-01-01 12:30:00', 'Brighton & Hove Albion FC', 'Chelsea FC', 1, 1)
# (264543, 'Premier League', '2020-01-01 15:00:00', 'Newcastle United FC', 'Leicester City FC', 0, 3)
# (264548, 'Premier League', '2020-01-01 15:00:00', 'Southampton FC', 'Tottenham Hotspur FC', 1, 0)
# (264550, 'Premier League', '2020-01-01 15:00:00', 'Watford FC', 'Wolverhampton Wanderers FC', 2, 1)
# (264542, 'Premier League', '2020-01-01 17:30:00', 'Manchester City FC', 'Everton FC', 2, 1)
# (264545, 'Premier League', '2020-01-01 17:30:00', 'Norwich City FC', 'Crystal Palace FC', 1, 1)
# (264547, 'Premier League', '2020-01-01 17:30:00', 'West Ham United FC', 'AFC Bournemouth', 4, 0)
# (264544, 'Premier League', '2020-01-01 20:00:00', 'Arsenal FC', 'Manchester United FC', 2, 0)
# (264541, 'Premier League', '2020-01-02 20:00:00', 'Liverpool FC', 'Sheffield United FC', 2, 0)

# %% [markdown]
# #### Result as Pandas Dataframe

# %%
df = pd.read_sql_query("SELECT * FROM football Limte ;", conn)
df
# Out:
#         id             div            date_time                   home_team  \
# 0   264524  Premier League  2019-12-26 12:30:00        Tottenham Hotspur FC
# 1   264522  Premier League  2019-12-26 15:00:00              Aston Villa FC
# 2   264523  Premier League  2019-12-26 15:00:00                  Chelsea FC
# 3   264525  Premier League  2019-12-26 15:00:00                  Everton FC
# 4   264527  Premier League  2019-12-26 15:00:00         Sheffield United FC
# 5   264529  Premier League  2019-12-26 15:00:00           Crystal Palace FC
# 6   264530  Premier League  2019-12-26 15:00:00             AFC Bournemouth
# 7   264526  Premier League  2019-12-26 17:30:00        Manchester United FC
# 8   264528  Premier League  2019-12-26 20:00:00           Leicester City FC
# 9   264521  Premier League  2019-12-27 19:45:00  Wolverhampton Wanderers FC
# 10  264539  Premier League  2019-12-28 12:30:00   Brighton & Hove Albion FC
# 11  264533  Premier League  2019-12-28 15:00:00         Newcastle United FC
# 12  264538  Premier League  2019-12-28 15:00:00              Southampton FC
# 13  264540  Premier League  2019-12-28 15:00:00                  Watford FC
# 14  264535  Premier League  2019-12-28 17:30:00             Norwich City FC
# 15  264537  Premier League  2019-12-28 17:30:00          West Ham United FC
# 16  264536  Premier League  2019-12-28 19:45:00                  Burnley FC
# 17  264534  Premier League  2019-12-29 14:00:00                  Arsenal FC
# 18  264531  Premier League  2019-12-29 16:30:00                Liverpool FC
# 19  264532  Premier League  2019-12-29 18:00:00          Manchester City FC
# 20  264546  Premier League  2020-01-01 12:30:00                  Burnley FC
# 21  264549  Premier League  2020-01-01 12:30:00   Brighton & Hove Albion FC
# 22  264543  Premier League  2020-01-01 15:00:00         Newcastle United FC
# 23  264548  Premier League  2020-01-01 15:00:00              Southampton FC
# 24  264550  Premier League  2020-01-01 15:00:00                  Watford FC
# 25  264542  Premier League  2020-01-01 17:30:00          Manchester City FC
# 26  264545  Premier League  2020-01-01 17:30:00             Norwich City FC
# 27  264547  Premier League  2020-01-01 17:30:00          West Ham United FC
# 28  264544  Premier League  2020-01-01 20:00:00                  Arsenal FC
# 29  264541  Premier League  2020-01-02 20:00:00                Liverpool FC
#
#                      away_team  fthg  ftag
# 0    Brighton & Hove Albion FC     2     1
# 1              Norwich City FC     1     0
# 2               Southampton FC     0     2
# 3                   Burnley FC     1     0
# 4                   Watford FC     1     1
# 5           West Ham United FC     2     1
# 6                   Arsenal FC     1     1
# 7          Newcastle United FC     4     1
# 8                 Liverpool FC     0     4
# 9           Manchester City FC     3     2
# 10             AFC Bournemouth     2     0
# 11                  Everton FC     1     2
# 12           Crystal Palace FC     1     1
# 13              Aston Villa FC     3     0
# 14        Tottenham Hotspur FC     2     2
# 15           Leicester City FC     1     2
# 16        Manchester United FC     0     2
# 17                  Chelsea FC     1     2
# 18  Wolverhampton Wanderers FC     1     0
# 19         Sheffield United FC     2     0
# 20              Aston Villa FC     1     2
# 21                  Chelsea FC     1     1
# 22           Leicester City FC     0     3
# 23        Tottenham Hotspur FC     1     0
# 24  Wolverhampton Wanderers FC     2     1
# 25                  Everton FC     2     1
# 26           Crystal Palace FC     1     1
# 27             AFC Bournemouth     4     0
# 28        Manchester United FC     2     0
# 29         Sheffield United FC     2     0

# %%
pd.read_sql_query("Select * from football where date_time <'2020-01-01 12:30:00' and fthg!= 0 and ftag != 0  ;", conn)
# Out:
#         id             div            date_time                   home_team  \
# 0   264524  Premier League  2019-12-26 12:30:00        Tottenham Hotspur FC
# 1   264527  Premier League  2019-12-26 15:00:00         Sheffield United FC
# 2   264529  Premier League  2019-12-26 15:00:00           Crystal Palace FC
# 3   264530  Premier League  2019-12-26 15:00:00             AFC Bournemouth
# 4   264526  Premier League  2019-12-26 17:30:00        Manchester United FC
# 5   264521  Premier League  2019-12-27 19:45:00  Wolverhampton Wanderers FC
# 6   264533  Premier League  2019-12-28 15:00:00         Newcastle United FC
# 7   264538  Premier League  2019-12-28 15:00:00              Southampton FC
# 8   264535  Premier League  2019-12-28 17:30:00             Norwich City FC
# 9   264537  Premier League  2019-12-28 17:30:00          West Ham United FC
# 10  264534  Premier League  2019-12-29 14:00:00                  Arsenal FC
#
#                     away_team  fthg  ftag
# 0   Brighton & Hove Albion FC     2     1
# 1                  Watford FC     1     1
# 2          West Ham United FC     2     1
# 3                  Arsenal FC     1     1
# 4         Newcastle United FC     4     1
# 5          Manchester City FC     3     2
# 6                  Everton FC     1     2
# 7           Crystal Palace FC     1     1
# 8        Tottenham Hotspur FC     2     2
# 9           Leicester City FC     1     2
# 10                 Chelsea FC     1     2

# %% [markdown]
# #                                             THANK YOU

# %%
#Football_data['Date'] = Football_data['utcDate'].dt.date
#Football_data['Time'] = [datetime.datetime.time(d) for d in Football_data['utcDate']] 
###Football_data1=Football_data[['Date','Time','utcDate','awayTeam.id', 'homeTeam.id', 'competition.name', 'awayTeam.name', 'homeTeam.name','score.fullTime.awayTeam','score.fullTime.homeTeam']]

# %%
#Football_data=Football_data[['id','utcDate', 'competition.name', 'awayTeam.name', 'homeTeam.name','score.fullTime.awayTeam','score.fullTime.homeTeam']]
